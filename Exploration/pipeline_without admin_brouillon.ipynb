# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from utils import add_Loss, clean_data

# %% [markdown]
# ## Import and clean data

# %%
#Select the dataset of one season of one year
YEAR = 2019
SEASON = "Kharif" # "Rabi" 

#Path to the dataset
pathData = f"Data\RawDataUnified\RawData_{YEAR}_{SEASON}"
print(pathData)


df = pd.read_csv(pathData)
# Out:
# Data\RawDataUnified\RawData_2019_Kharif
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Clean an add loss to data
df=add_Loss(clean_data(df))
df
# Out:
#                                                          Crop  Area Sown (Ha)  \
# key
# andhra pradesh_anantapur_agali__agali                   Arhar      340.012294
# andhra pradesh_anantapur_agali__akkagaladevarah...      Arhar      340.012294
# andhra pradesh_anantapur_agali__hulikeradevarah...      Arhar      340.012294
# andhra pradesh_anantapur_agali__inagalore               Arhar      340.012294
# andhra pradesh_anantapur_agali__kodihalli               Arhar      340.012294
# ...                                                       ...             ...
# west bengal_uttar dinajpur__hemtabad__              Aus Paddy      340.012294
# west bengal_uttar dinajpur__itahar__                Aus Paddy      340.012294
# west bengal_uttar dinajpur__kaliaganj__             Aus Paddy      340.012294
# west bengal_uttar dinajpur__karandighi__            Aus Paddy      340.012294
# west bengal_uttar dinajpur__raiganj__               Aus Paddy      340.012294
#
#                                                     Area Insured (Ha)  \
# key
# andhra pradesh_anantapur_agali__agali                        0.168514
# andhra pradesh_anantapur_agali__akkagaladevarah...           0.168514
# andhra pradesh_anantapur_agali__hulikeradevarah...           0.168514
# andhra pradesh_anantapur_agali__inagalore                    0.168514
# andhra pradesh_anantapur_agali__kodihalli                    0.168514
# ...                                                               ...
# west bengal_uttar dinajpur__hemtabad__                       1.857143
# west bengal_uttar dinajpur__itahar__                         1.857143
# west bengal_uttar dinajpur__kaliaganj__                      1.857143
# west bengal_uttar dinajpur__karandighi__                     1.857143
# west bengal_uttar dinajpur__raiganj__                        1.857143
#
#                                                     SI Per Ha (Inr/Ha)  \
# key
# andhra pradesh_anantapur_agali__agali                          28750.0
# andhra pradesh_anantapur_agali__akkagaladevarah...             28750.0
# andhra pradesh_anantapur_agali__hulikeradevarah...             28750.0
# andhra pradesh_anantapur_agali__inagalore                      28750.0
# andhra pradesh_anantapur_agali__kodihalli                      28750.0
# ...                                                                ...
# west bengal_uttar dinajpur__hemtabad__                         60500.0
# west bengal_uttar dinajpur__itahar__                           60500.0
# west bengal_uttar dinajpur__kaliaganj__                        60500.0
# west bengal_uttar dinajpur__karandighi__                       60500.0
# west bengal_uttar dinajpur__raiganj__                          60500.0
#
#                                                     Sum Insured (Inr)  \
# key
# andhra pradesh_anantapur_agali__agali                     4844.772967
# andhra pradesh_anantapur_agali__akkagaladevarah...        4844.772967
# andhra pradesh_anantapur_agali__hulikeradevarah...        4844.772967
# andhra pradesh_anantapur_agali__inagalore                 4844.772967
# andhra pradesh_anantapur_agali__kodihalli                 4844.772967
# ...                                                               ...
# west bengal_uttar dinajpur__hemtabad__                  112357.142857
# west bengal_uttar dinajpur__itahar__                    112357.142857
# west bengal_uttar dinajpur__kaliaganj__                 112357.142857
# west bengal_uttar dinajpur__karandighi__                112357.142857
# west bengal_uttar dinajpur__raiganj__                   112357.142857
#
#                                                     Indemnity Level  \
# key
# andhra pradesh_anantapur_agali__agali                           0.8
# andhra pradesh_anantapur_agali__akkagaladevarah...              0.8
# andhra pradesh_anantapur_agali__hulikeradevarah...              0.8
# andhra pradesh_anantapur_agali__inagalore                       0.8
# andhra pradesh_anantapur_agali__kodihalli                       0.8
# ...                                                             ...
# west bengal_uttar dinajpur__hemtabad__                          0.9
# west bengal_uttar dinajpur__itahar__                            0.9
# west bengal_uttar dinajpur__kaliaganj__                         0.9
# west bengal_uttar dinajpur__karandighi__                        0.9
# west bengal_uttar dinajpur__raiganj__                           0.9
#
#                                                      2002 Yield   2003 Yield  \
# key
# andhra pradesh_anantapur_agali__agali               1095.885896  1351.243458
# andhra pradesh_anantapur_agali__akkagaladevarah...  1095.885896  1351.243458
# andhra pradesh_anantapur_agali__hulikeradevarah...  1095.885896  1351.243458
# andhra pradesh_anantapur_agali__inagalore           1095.885896  1351.243458
# andhra pradesh_anantapur_agali__kodihalli           1095.885896  1351.243458
# ...                                                         ...          ...
# west bengal_uttar dinajpur__hemtabad__              1095.885896  1351.243458
# west bengal_uttar dinajpur__itahar__                1095.885896  1351.243458
# west bengal_uttar dinajpur__kaliaganj__             1095.885896  1351.243458
# west bengal_uttar dinajpur__karandighi__            1095.885896  1351.243458
# west bengal_uttar dinajpur__raiganj__               1095.885896  1351.243458
#
#                                                      2004 Yield   2005 Yield  \
# key
# andhra pradesh_anantapur_agali__agali               1241.526926  1384.386989
# andhra pradesh_anantapur_agali__akkagaladevarah...  1241.526926  1384.386989
# andhra pradesh_anantapur_agali__hulikeradevarah...  1241.526926  1384.386989
# andhra pradesh_anantapur_agali__inagalore           1241.526926  1384.386989
# andhra pradesh_anantapur_agali__kodihalli           1241.526926  1384.386989
# ...                                                         ...          ...
# west bengal_uttar dinajpur__hemtabad__              1241.526926  1591.450000
# west bengal_uttar dinajpur__itahar__                1241.526926  1591.450000
# west bengal_uttar dinajpur__kaliaganj__             1241.526926  1591.450000
# west bengal_uttar dinajpur__karandighi__            1241.526926  1591.450000
# west bengal_uttar dinajpur__raiganj__               1241.526926  1591.450000
#
#                                                     ...   2009 Yield  \
# key                                                 ...
# andhra pradesh_anantapur_agali__agali               ...   264.534667
# andhra pradesh_anantapur_agali__akkagaladevarah...  ...   264.534667
# andhra pradesh_anantapur_agali__hulikeradevarah...  ...   264.534667
# andhra pradesh_anantapur_agali__inagalore           ...   264.534667
# andhra pradesh_anantapur_agali__kodihalli           ...   264.534667
# ...                                                 ...          ...
# west bengal_uttar dinajpur__hemtabad__              ...  1479.010000
# west bengal_uttar dinajpur__itahar__                ...  1479.010000
# west bengal_uttar dinajpur__kaliaganj__             ...  1053.080000
# west bengal_uttar dinajpur__karandighi__            ...  1479.010000
# west bengal_uttar dinajpur__raiganj__               ...  1620.980000
#
#                                                      2010 Yield   2011 Yield  \
# key
# andhra pradesh_anantapur_agali__agali                150.820333    87.096222
# andhra pradesh_anantapur_agali__akkagaladevarah...   150.820333    87.096222
# andhra pradesh_anantapur_agali__hulikeradevarah...   150.820333    87.096222
# andhra pradesh_anantapur_agali__inagalore            150.820333    87.096222
# andhra pradesh_anantapur_agali__kodihalli            150.820333    87.096222
# ...                                                         ...          ...
# west bengal_uttar dinajpur__hemtabad__              1814.600000  1748.970000
# west bengal_uttar dinajpur__itahar__                1814.600000  1748.970000
# west bengal_uttar dinajpur__kaliaganj__             1641.160000  1406.630000
# west bengal_uttar dinajpur__karandighi__            1814.600000  1748.970000
# west bengal_uttar dinajpur__raiganj__               1872.410000  1863.080000
#
#                                                     2012 Yield  2013 Yield  \
# key
# andhra pradesh_anantapur_agali__agali                  108.775       70.00
# andhra pradesh_anantapur_agali__akkagaladevarah...     108.775       58.00
# andhra pradesh_anantapur_agali__hulikeradevarah...     108.775       67.00
# andhra pradesh_anantapur_agali__inagalore              108.775       62.00
# andhra pradesh_anantapur_agali__kodihalli              108.775       70.00
# ...                                                        ...         ...
# west bengal_uttar dinajpur__hemtabad__                1781.370     1942.86
# west bengal_uttar dinajpur__itahar__                  1781.370     1942.86
# west bengal_uttar dinajpur__kaliaganj__               1781.370     1942.86
# west bengal_uttar dinajpur__karandighi__              1781.370     1942.86
# west bengal_uttar dinajpur__raiganj__                 1781.370     1942.86
#
#                                                     2014 Yield  2015 Yield  \
# key
# andhra pradesh_anantapur_agali__agali                   295.00       89.00
# andhra pradesh_anantapur_agali__akkagaladevarah...      232.00      120.00
# andhra pradesh_anantapur_agali__hulikeradevarah...      295.00       89.00
# andhra pradesh_anantapur_agali__inagalore               232.00      120.00
# andhra pradesh_anantapur_agali__kodihalli               295.00       89.00
# ...                                                        ...         ...
# west bengal_uttar dinajpur__hemtabad__                 2086.49     2346.79
# west bengal_uttar dinajpur__itahar__                   2086.49     2346.79
# west bengal_uttar dinajpur__kaliaganj__                2086.49     2346.79
# west bengal_uttar dinajpur__karandighi__               2086.49     2346.79
# west bengal_uttar dinajpur__raiganj__                  2086.49     2346.79
#
#                                                      2016 Yield   2017 Yield  \
# key
# andhra pradesh_anantapur_agali__agali                 99.000000  2021.056993
# andhra pradesh_anantapur_agali__akkagaladevarah...    99.000000  2021.056993
# andhra pradesh_anantapur_agali__hulikeradevarah...    99.000000  2021.056993
# andhra pradesh_anantapur_agali__inagalore             99.000000  2021.056993
# andhra pradesh_anantapur_agali__kodihalli             99.000000  2021.056993
# ...                                                         ...          ...
# west bengal_uttar dinajpur__hemtabad__              2084.736928  2021.056993
# west bengal_uttar dinajpur__itahar__                2084.736928  2021.056993
# west bengal_uttar dinajpur__kaliaganj__             2084.736928  2021.056993
# west bengal_uttar dinajpur__karandighi__            2084.736928  2021.056993
# west bengal_uttar dinajpur__raiganj__               2084.736928  2021.056993
#
#                                                             Loss
# key
# andhra pradesh_anantapur_agali__agali               12521.074567
# andhra pradesh_anantapur_agali__akkagaladevarah...  12811.484033
# andhra pradesh_anantapur_agali__hulikeradevarah...  12521.074567
# andhra pradesh_anantapur_agali__inagalore           12811.484033
# andhra pradesh_anantapur_agali__kodihalli           12521.074567
# ...                                                          ...
# west bengal_uttar dinajpur__hemtabad__                  0.000000
# west bengal_uttar dinajpur__itahar__                    0.000000
# west bengal_uttar dinajpur__kaliaganj__                 0.000000
# west bengal_uttar dinajpur__karandighi__                0.000000
# west bengal_uttar dinajpur__raiganj__                   0.000000
#
# [372909 rows x 23 columns]

# %% [markdown]
# ## UMAP embeding

# %%
import umap
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings("ignore")


# #Preprocessing numerical
numerical = df.select_dtypes(exclude='object')

for c in numerical.columns:
    pt = PowerTransformer()
    numerical.loc[:, c] = pt.fit_transform(np.array(numerical[c]).reshape(-1, 1))
    
##preprocessing categorical
categorical = df.select_dtypes(include='object')
categorical = pd.get_dummies(categorical)

#Percentage of columns which are categorical is used as weight parameter in embeddings later
categorical_weight = len(df.select_dtypes(include='object').columns) / df.shape[1]

# %%
# from umap import UMAP

fit1 = umap.UMAP(metric='l2').fit(numerical)
fit2 = umap.UMAP(metric='dice').fit(categorical)

# %%
import umap.umap_ as uu

# #Augmenting the numerical embedding with categorical
intersection = uu.general_simplicial_set_intersection(fit1.graph_, fit2.graph_, weight=categorical_weight)
intersection = uu.reset_local_connectivity(intersection)
embedding = uu.simplicial_set_embedding(fit1._raw_data, intersection, fit1.n_components, 
                                                fit1._initial_alpha, fit1._a, fit1._b, 
                                                fit1.repulsion_strength, fit1.negative_sample_rate, 
                                                200, 'random', np.random, fit1.metric, 
                                                fit1._metric_kwds, False, densmap_kwds="Salut", output_dens=False)


embedding=embedding[0]
np.save(f"embedding_{SEASON}",embedding)

# %%
plt.figure(figsize=(20, 10))
plt.scatter(*embedding.T, s=2, cmap='Spectral', alpha=1.0)
plt.show()

# %% [markdown]
# ## K-Prototypes

# %%
# full_data=df.copy(deep=True)
# import kmodes
# from kmodes.kprototypes import KPrototypes

# %%
# kprot_data = full_data.copy()
# #Pre-processing
# for c in full_data.select_dtypes(exclude='object').columns:
#     pt = PowerTransformer()
#     kprot_data[c] =  pt.fit_transform(np.array(kprot_data[c]).reshape(-1, 1))

# categorical_columns = [1,2,3] #make sure to specify correct indices

# #Actual clustering
# kproto = KPrototypes(n_clusters= 15, init='Cao', n_jobs = 4)
# clusters = kproto.fit_predict(kprot_data, categorical=categorical_columns)

# #long à tourner : environ 8 min

# %%
# #Prints the count of each cluster group
# pd.Series(clusters).value_counts()
# Out:
# 13    2984
# 2     2804
# 4     1988
# 11    1925
# 12    1757
# 3     1675
# 8     1526
# 14    1026
# 5      975
# 1      966
# 7      341
# 10     268
# 9      235
# 6      166
# 0       99
# dtype: int64

# %%
# #OPTIONAL: Elbow plot with cost (will take a LONG time)
# costs = []
# n_clusters = []
# clusters_assigned = []

# for i in tqdm(range(2, 25)):
#     try:
#         kproto = KPrototypes(n_clusters= i, init='Cao', verbose=2)
#         clusters = kproto.fit_predict(kprot_data, categorical=[0, 6, 7, 9, 13])
#         costs.append(kproto.cost_)
#         n_clusters.append(i)
#         clusters_assigned.append(clusters)
#     except:
#         print(f"Can't cluster with {i} clusters")
        
# fig = go.Figure(data=go.Scatter(x=n_clusters, y=costs ))
# fig.show()

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches((20, 10))
# embedding=embedding[0]
# scatter = ax.scatter(embedding[:, 0], embedding[:, 1], s=2, c=clusters, cmap='tab20b', alpha=1.0)

# # produce a legend with the unique colors from the scatter
# legend1 = ax.legend(*scatter.legend_elements(num=15),
#                     loc="lower left", title="Classes")
# ax.add_artist(legend1)

# %% [markdown]
# ## K-means (for mixed data)

# %%
from sklearn.cluster import KMeans
full_data=df.copy(deep=True)

# %%
#One-Hot-Encoding
data = pd.get_dummies(full_data)

#Pre-processing
for c in data.columns:
    pt = PowerTransformer()
    data.loc[:, c] = pt.fit_transform(np.array(data[c]).reshape(-1, 1))

#Actual Clustering
kmeans = KMeans(n_clusters=10).fit(data)
kmeans_labels = kmeans.labels_

# %%
# #OPTIONAL: Elbow plot with inertia
# #Elbow method to choose the optimal number of clusters
# sse = {}
# for k in tqdm(range(2, 50)):
#     kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data)
#     sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
    
# fig = go.Figure(data=go.Scatter(x=list(sse.keys()), y=list(sse.values())))
# fig.show()

# %%
# embedding=embedding[0] #because tuple #comment if load embedding
embedding = np.load("Outputs/embedding_Rabi.npy")

fig, ax = plt.subplots()
fig.set_size_inches((20, 10))
scatter = ax.scatter(embedding[:, 0], embedding[:, 1], s=2, c=kmeans_labels, cmap='tab20b', alpha=1.0)

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(num=10),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)

# %% [markdown]
# ## Implémentation critère cluster

# %%
from sklearn.metrics import davies_bouldin_score


results = {}

for i in range(5,15):
    kmeans = KMeans(n_clusters=i, random_state=30).fit(data)
    labels = kmeans.labels_
    db_index = davies_bouldin_score(data, labels)
    print(db_index)
    results.update({i: db_index})


plt.plot(list(results.keys()), list(results.values()))
plt.xlabel("Number of clusters")
plt.ylabel("Davies-Boulding Index")
plt.show()
# Out:
# 2.1171544533934035
# 2.043593446117891
# 2.2951566733481417
# 1.8876108125150748
# 2.0025663314017264
# 1.8847462609441614
# 2.2520353732683493
# 2.0752898646620435
# 2.5163502358783276
# 1.6490062345337468
