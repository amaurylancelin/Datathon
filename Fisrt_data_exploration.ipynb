# %% [markdown]
# # Exploratory Data analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
pathData = "RawData/2017/2017_Andhra Pradesh_Kharif.xlsx"
#racine = "RawData/"
#pathData = racine+ "2017/2017_Andhra Pradesh_Kharif.xlsx"
print(pathData)
# Out:
# RawData/2017/2017_Andhra Pradesh_Kharif.xlsx

# %%
df = pd.read_excel(pathData)

# %%
df
# Out:
#                 State  Cluster   District Sub-District  Block  \
# 0      Andhra Pradesh        1  Anantapur        AGALI    NaN
# 1      Andhra Pradesh        1  Anantapur        AGALI    NaN
# 2      Andhra Pradesh        1  Anantapur        AGALI    NaN
# 3      Andhra Pradesh        1  Anantapur        AGALI    NaN
# 4      Andhra Pradesh        1  Anantapur        AGALI    NaN
# ...               ...      ...        ...          ...    ...
# 18730  Andhra Pradesh        1  Anantapur     TADPATRI    NaN
# 18731  Andhra Pradesh        1  Anantapur   URAVAKONDA    NaN
# 18732  Andhra Pradesh        1  Anantapur   VAJRAKARUR    NaN
# 18733  Andhra Pradesh        1  Anantapur  VIDAPANAKAL    NaN
# 18734  Andhra Pradesh        1  Anantapur     YELLANUR    NaN
#
#                         GP  Season   Crop  Area Sown (Ha)  Area Insured (Ha)  \
# 0                    AGALI  Kharif  Arhar       40.623418           1.282330
# 1      AKKAGALADEVARAHALLI  Kharif  Arhar       40.623418           1.282330
# 2      HULIKERADEVARAHALLI  Kharif  Arhar       40.623418           1.282330
# 3                INAGALORE  Kharif  Arhar       40.623418           1.282330
# 4                KODIHALLI  Kharif  Arhar       40.623418           1.282330
# ...                    ...     ...    ...             ...                ...
# 18730                  NaN  Kharif  Paddy      513.435897          53.271821
# 18731                  NaN  Kharif  Paddy      513.435897          53.271821
# 18732                  NaN  Kharif  Paddy      513.435897          53.271821
# 18733                  NaN  Kharif  Paddy      513.435897          53.271821
# 18734                  NaN  Kharif  Paddy      513.435897          53.271821
#
#        ...   2009 Yield   2010 Yield  2011 Yield   2012 Yield  2013 Yield  \
# 0      ...   249.548869   165.490615    87.72849   160.931593     70.0000
# 1      ...   249.548869   165.490615    87.72849   160.931593     58.0000
# 2      ...   249.548869   165.490615    87.72849   160.931593     67.0000
# 3      ...   249.548869   165.490615    87.72849   160.931593     62.0000
# 4      ...   249.548869   165.490615    87.72849   160.931593     70.0000
# ...    ...          ...          ...         ...          ...         ...
# 18730  ...  2833.552000  2589.686381  2134.02000  2372.582000   1047.4110
# 18731  ...  1545.467000  1370.196000  1204.45700  1019.457000   1084.3280
# 18732  ...  3025.253263  2303.245000  2601.39600  2338.307000   2169.1475
# 18733  ...  2418.685000  2308.729000  2139.97500  3617.316000   3648.8540
# 18734  ...  3025.253263  2379.628000  2437.05100  2438.648381   1866.8420
#
#        2014 Yield  2015 Yield  2016 Yield  2017 Yield  2018 Yield
# 0       295.00000    89.00000         NaN         NaN         NaN
# 1       232.00000   120.00000         NaN         NaN         NaN
# 2       295.00000    89.00000         NaN         NaN         NaN
# 3       232.00000   120.00000         NaN         NaN         NaN
# 4       295.00000    89.00000         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 18730  1575.59100  1501.63900         NaN         NaN         NaN
# 18731  2787.30900  1945.91100         NaN         NaN         NaN
# 18732  1329.44200  1990.33800         NaN         NaN         NaN
# 18733  3854.35000  3547.06700         NaN         NaN         NaN
# 18734  2564.14495  2513.28555         NaN         NaN         NaN
#
# [18735 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['State', 'Cluster', 'District', 'Sub-District', 'Block', 'GP', 'Season',
#        'Crop', 'Area Sown (Ha)', 'Area Insured (Ha)', 'SI Per Ha (Inr/Ha)',
#        'Sum Insured (Inr)', 'Indemnity Level', '2000 Yield', '2001 Yield',
#        '2002 Yield', '2003 Yield', '2004 Yield', '2005 Yield', '2006 Yield',
#        '2007 Yield', '2008 Yield', '2009 Yield', '2010 Yield', '2011 Yield',
#        '2012 Yield', '2013 Yield', '2014 Yield', '2015 Yield', '2016 Yield',
#        '2017 Yield', '2018 Yield'],
#       dtype='object')

# %%
df["Indemnity Level"].unique()
# Out:
# array([0.8, 0.9])

# %%
df['Cluster'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df["Indemnity Level"]
# Out:
# 0        0.8
# 1        0.8
# 2        0.8
# 3        0.8
# 4        0.8
#         ...
# 18730    0.8
# 18731    0.8
# 18732    0.8
# 18733    0.8
# 18734    0.8
# Name: Indemnity Level, Length: 18735, dtype: float64

# %% [markdown]
# ### Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18735 entries, 0 to 18734
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               18735 non-null  object
#  1   Cluster             18735 non-null  int64
#  2   District            18735 non-null  object
#  3   Sub-District        18735 non-null  object
#  4   Block               0 non-null      float64
#  5   GP                  17617 non-null  object
#  6   Season              18735 non-null  object
#  7   Crop                18735 non-null  object
#  8   Area Sown (Ha)      18735 non-null  float64
#  9   Area Insured (Ha)   18735 non-null  float64
#  10  SI Per Ha (Inr/Ha)  18735 non-null  int64
#  11  Sum Insured (Inr)   18735 non-null  float64
#  12  Indemnity Level     18735 non-null  float64
#  13  2000 Yield          0 non-null      float64
#  14  2001 Yield          0 non-null      float64
#  15  2002 Yield          0 non-null      float64
#  16  2003 Yield          0 non-null      float64
#  17  2004 Yield          0 non-null      float64
#  18  2005 Yield          0 non-null      float64
#  19  2006 Yield          16829 non-null  float64
#  20  2007 Yield          17777 non-null  float64
#  21  2008 Yield          18602 non-null  float64
#  22  2009 Yield          18645 non-null  float64
#  23  2010 Yield          18668 non-null  float64
#  24  2011 Yield          18735 non-null  float64
#  25  2012 Yield          18735 non-null  float64
#  26  2013 Yield          18735 non-null  float64
#  27  2014 Yield          18735 non-null  float64
#  28  2015 Yield          18715 non-null  float64
#  29  2016 Yield          8953 non-null   float64
#  30  2017 Yield          0 non-null      float64
#  31  2018 Yield          0 non-null      float64
# dtypes: float64(24), int64(2), object(6)
# memory usage: 4.6+ MB

# %%
#Suppresion des colonnes sans valeur non nulle
df = df.drop(columns = ["Block","2000 Yield","2001 Yield","2002 Yield","2003 Yield","2004 Yield","2005 Yield","2017 Yield","2018 Yield"])
#Suppression des colonnes inutiles
df = df.drop(columns = ["State","District","Sub-District","GP"])

# %%
#On remplace les rendements nuls par leur moyenne
for year in range(2006,2017):
    df[str(year) + " Yield"] = df[str(year) + " Yield"].fillna(df[str(year) + " Yield"].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18735 entries, 0 to 18734
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cluster             18735 non-null  int64
#  1   Season              18735 non-null  object
#  2   Crop                18735 non-null  object
#  3   Area Sown (Ha)      18735 non-null  float64
#  4   Area Insured (Ha)   18735 non-null  float64
#  5   SI Per Ha (Inr/Ha)  18735 non-null  int64
#  6   Sum Insured (Inr)   18735 non-null  float64
#  7   Indemnity Level     18735 non-null  float64
#  8   2006 Yield          18735 non-null  float64
#  9   2007 Yield          18735 non-null  float64
#  10  2008 Yield          18735 non-null  float64
#  11  2009 Yield          18735 non-null  float64
#  12  2010 Yield          18735 non-null  float64
#  13  2011 Yield          18735 non-null  float64
#  14  2012 Yield          18735 non-null  float64
#  15  2013 Yield          18735 non-null  float64
#  16  2014 Yield          18735 non-null  float64
#  17  2015 Yield          18735 non-null  float64
#  18  2016 Yield          18735 non-null  float64
# dtypes: float64(15), int64(2), object(2)
# memory usage: 2.7+ MB

# %%
df["2010 Yield"].min(),df["2010 Yield"].max()
# Out:
# (0.0, 129974.0)

# %%
yield_by_year = []
for year in range(2006,2017):
    yield_by_year.append(df[str(year) + " Yield"].mean())
plt.plot(range(2006,2017),yield_by_year)
plt.title("Evolution des récoltes moyennes")
plt.xlabel("année")
plt.show()

print("Distribution des récoltes en fonction du district")
sn.violinplot("District","2006 Yield",data=df[df["District"].isin(pd.unique(df["District"])[:6])])
plt.show()
sn.violinplot("District","2006 Yield",data=df[df["District"].isin(pd.unique(df["District"])[6:])])
plt.show()
# Out:
# Distribution des récoltes en fonction du district
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2 = df[["Crop","2011 Yield","2012 Yield","SI Per Ha (Inr/Ha)","Indemnity Level"]]
df2 = pd.get_dummies(df2)
plt.figure(figsize=(10, 10))
corrMatrix = df2.corr()
corrMatrix2 = corrMatrix.copy(deep = True)

for param in corrMatrix2.columns:
    corrMatrix2.loc[corrMatrix[param] >-2, param] = True
    corrMatrix2.loc[corrMatrix[param] >0.5, param] = False
    corrMatrix2.loc[corrMatrix[param] <-0.5, param] = False
plt.figure(figsize=(9, 9))
sn.heatmap(corrMatrix, annot=True,mask=corrMatrix2)
plt.show()

# %%
# from sklearn.preprocessing import PowerTransformer
# import umap

# #Preprocessing numerical
# numerical = df.select_dtypes(exclude='object')

# for c in numerical.columns:
#     pt = PowerTransformer()
#     numerical.loc[:, c] = pt.fit_transform(np.array(numerical[c]).reshape(-1, 1))
    
# ##preprocessing categorical
# categorical = df.select_dtypes(include='object')
# categorical = pd.get_dummies(categorical)

# #Percentage of columns which are categorical is used as weight parameter in embeddings later
# categorical_weight = len(df.select_dtypes(include='object').columns) / df.shape[1]

# #Embedding numerical & categorical
# fit1 = umap.UMAP(metric='l2').fit(numerical)
# fit2 = umap.UMAP(metric='dice').fit(categorical)

# #Augmenting the numerical embedding with categorical
# intersection = umap.umap_.general_simplicial_set_intersection(fit1.graph_, fit2.graph_, weight=categorical_weight)
# intersection = umap.umap_.reset_local_connectivity(intersection)
# embedding = umap.umap_.simplicial_set_embedding(fit1._raw_data, intersection, fit1.n_components, 
#                                                 fit1._initial_alpha, fit1._a, fit1._b, 
#                                                 fit1.repulsion_strength, fit1.negative_sample_rate, 
#                                                 200, 'random', np.random, fit1.metric, 
#                                                 fit1._metric_kwds, False)

# plt.figure(figsize=(20, 10))
# plt.scatter(*embedding.T, s=2, cmap='Spectral', alpha=1.0)
# plt.show()
# Out:
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count
# C:\Users\Amaury Lancelin\anaconda3\lib\site-packages\pandas\core\indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\AMAURY~1\AppData\Local\Temp/ipykernel_16808/3165556791.py in <module>
#      17
#      18 #Embedding numerical & categorical
# ---> 19 fit1 = umap.UMAP(metric='l2').fit(numerical)
#      20 fit2 = umap.UMAP(metric='dice').fit(categorical)
#      21
#
# ~\anaconda3\lib\site-packages\umap\umap_.py in fit(self, X, y)
#    2267         """
#    2268
# -> 2269         X = check_array(X, dtype=np.float32, accept_sparse="csr", order="C")
#    2270         self._raw_data = X
#    2271
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
df['Crop']=pd.factorize(df['Crop'])[0]

# %%
df[df['GP']=='KOTHAPALLE']
# Out:
#                 State  Cluster        District    Sub-District  Block  \
# 401    Andhra Pradesh        1       Anantapur    KOTHACHERUVU    NaN
# 671    Andhra Pradesh        1       Anantapur     PUTTAPARTHI    NaN
# 784    Andhra Pradesh        1       Anantapur    SOMANDEPALLE    NaN
# 1112   Andhra Pradesh        2        Prakasam           DARSI    NaN
# 2148   Andhra Pradesh        1        Chittoor          KUPPAM    NaN
# 3428   Andhra Pradesh        2        Cuddapah       PRODDUTUR    NaN
# 3448   Andhra Pradesh        2        Cuddapah        RAJAMPET    NaN
# 3928   Andhra Pradesh        1   East Godavari         CHINTUR    NaN
# 4003   Andhra Pradesh        1   East Godavari      DEVIPATNAM    NaN
# 4109   Andhra Pradesh        1   East Godavari       GOKAVARAM    NaN
# 4755   Andhra Pradesh        1   East Godavari    RAJAVOMMANGI    NaN
# 5139   Andhra Pradesh        1   East Godavari    U.KOTHAPALLE    NaN
# 5693   Andhra Pradesh        1          Guntur        MACHERLA    NaN
# 6197   Andhra Pradesh        2         Krishna      BAPULAPADU    NaN
# 6301   Andhra Pradesh        2         Krishna    GAMPALAGUDEM    NaN
# 6350   Andhra Pradesh        2         Krishna      GHANTASALA    NaN
# 7266   Andhra Pradesh        2         Kurnool    BETHAMCHERLA    NaN
# 7529   Andhra Pradesh        2         Kurnool      KOTHAPALLE    NaN
# 8165   Andhra Pradesh        1         Nellore  DORAVARISATRAM    NaN
# 8242   Andhra Pradesh        1         Nellore          KAVALI    NaN
# 9061   Andhra Pradesh        2        Prakasam           DARSI    NaN
# 10769  Andhra Pradesh        1      Srikakulam     KOTABOMMALI    NaN
# 10957  Andhra Pradesh        1      Srikakulam         MANDASA    NaN
# 13760  Andhra Pradesh        2  Vishakhapatnam       KASIMKOTA    NaN
# 13860  Andhra Pradesh        2  Vishakhapatnam         KOYYURU    NaN
# 15518  Andhra Pradesh        2    Vizianagaram     GARUGUBILLI    NaN
# 16847  Andhra Pradesh        2   West Godavari       DENDULURU    NaN
# 16943  Andhra Pradesh        2   West Godavari     GANAPAVARAM    NaN
# 17148  Andhra Pradesh        2   West Godavari      LINGAPALEM    NaN
#
#                GP  Season  Crop  Area Sown (Ha)  Area Insured (Ha)  ...  \
# 401    KOTHAPALLE  Kharif     0       40.623418           1.282330  ...
# 671    KOTHAPALLE  Kharif     0       40.623418           1.282330  ...
# 784    KOTHAPALLE  Kharif     0       40.623418           1.282330  ...
# 1112   KOTHAPALLE  Kharif     0       84.513245           7.677307  ...
# 2148   KOTHAPALLE  Kharif     1        9.336967           7.330287  ...
# 3428   KOTHAPALLE  Kharif     1       22.575758          17.601212  ...
# 3448   KOTHAPALLE  Kharif     1       22.575758          17.601212  ...
# 3928   KOTHAPALLE  Kharif     1      127.450946          64.763416  ...
# 4003   KOTHAPALLE  Kharif     1      127.450946          64.763416  ...
# 4109   KOTHAPALLE  Kharif     1      127.450946          64.763416  ...
# 4755   KOTHAPALLE  Kharif     1      127.450946          64.763416  ...
# 5139   KOTHAPALLE  Kharif     1      127.450946          64.763416  ...
# 5693   KOTHAPALLE  Kharif     1      215.004016          27.904364  ...
# 6197   KOTHAPALLE  Kharif     1      209.560636          90.588469  ...
# 6301   KOTHAPALLE  Kharif     1      209.560636          90.588469  ...
# 6350   KOTHAPALLE  Kharif     1      209.560636          90.588469  ...
# 7266   KOTHAPALLE  Kharif     1       56.884371          29.311309  ...
# 7529   KOTHAPALLE  Kharif     1       56.884371          29.311309  ...
# 8165   KOTHAPALLE  Kharif     1       32.222222          35.944367  ...
# 8242   KOTHAPALLE  Kharif     1       32.222222          35.944367  ...
# 9061   KOTHAPALLE  Kharif     1        9.259409           5.786210  ...
# 10769  KOTHAPALLE  Kharif     1       94.303095          71.097919  ...
# 10957  KOTHAPALLE  Kharif     1       94.303095          71.097919  ...
# 13760  KOTHAPALLE  Kharif     1       27.461329           6.818058  ...
# 13860  KOTHAPALLE  Kharif     1       27.461329           6.818058  ...
# 15518  KOTHAPALLE  Kharif     1       76.002586          28.287007  ...
# 16847  KOTHAPALLE  Kharif     1      239.694093         133.507384  ...
# 16943  KOTHAPALLE  Kharif     1      239.694093         133.507384  ...
# 17148  KOTHAPALLE  Kharif     1      239.694093         133.507384  ...
#
#         2009 Yield   2010 Yield   2011 Yield   2012 Yield   2013 Yield  \
# 401     249.548869   165.490615    87.728490   160.931593   448.000000
# 671     249.548869   165.490615    87.728490   160.931593   386.000000
# 784     249.548869   165.490615    87.728490   160.931593   157.000000
# 1112    509.682603   606.167000   527.542000   852.458000   806.917000
# 2148   2556.641622  2698.561877  2670.044897  2640.000000  4405.000000
# 3428   2324.461000  1203.820000  2905.645000  2165.000000  3231.000000
# 3448   2663.373000  3356.962000  2600.530000  2846.000000  2838.000000
# 3928   2185.001109  2043.432362  1985.793298  1702.440292  1772.548757
# 4003    926.000000  2283.000000   313.000000  1085.000000   693.000000
# 4109   2234.000000  3375.000000   879.000000  2536.000000  2475.000000
# 4755   1250.000000  1904.000000   928.000000  2109.000000  1793.000000
# 5139   2545.000000  1797.000000  2809.000000  1052.000000   919.000000
# 5693   3604.000000  3112.000000  3683.000000  4112.000000  3774.000000
# 6197   3711.000000  3763.000000  4698.000000  3900.000000  4177.000000
# 6301   2210.000000  1294.000000  2464.000000  3532.000000  3158.000000
# 6350   3333.000000  3309.000000  4310.000000  4135.000000  4058.000000
# 7266   2816.526118  2859.587855  2767.969947  3155.000000  1937.000000
# 7529   5387.568000  1827.594000  2260.716000  3534.000000  2418.000000
# 8165   2880.000000  2747.000000  3361.000000  3357.000000  2844.000000
# 8242   4724.000000  3887.000000  2505.000000     0.000000   886.000000
# 9061   3909.000000  3325.537000  4209.000000  4163.000000  4611.000000
# 10769  1719.000000   458.000000   591.000000  2750.000000  1695.000000
# 10957  1302.000000   781.000000   859.000000  1880.000000  1721.000000
# 13760   619.000000  2567.000000   752.000000  1565.000000  1235.000000
# 13860  1471.000000  2229.000000   984.000000  1758.000000  1625.000000
# 15518  3141.000000  3004.000000  3154.000000  2048.000000  3080.000000
# 16847  3555.000000  3327.000000  3412.000000  2392.000000  3437.000000
# 16943  3350.000000  2848.000000  3173.000000   640.000000  2625.000000
# 17148  2724.000000  2399.000000  2517.000000  3288.000000  3063.000000
#
#         2014 Yield  2015 Yield  2016 Yield  2017 Yield  2018 Yield
# 401      31.000000     320.000         NaN         NaN         NaN
# 671      61.000000     181.000         NaN         NaN         NaN
# 784      42.000000     147.000         NaN         NaN         NaN
# 1112   1030.083000    1088.083         NaN         NaN         NaN
# 2148   3737.000000    2649.000      4052.0         NaN         NaN
# 3428   3388.000000    3341.000         NaN         NaN         NaN
# 3448   3251.000000    3240.000         NaN         NaN         NaN
# 3928   2485.363236    1283.000      1295.0         NaN         NaN
# 4003   1530.000000    1971.000      2548.0         NaN         NaN
# 4109   3294.000000    3217.000      3239.0         NaN         NaN
# 4755   2065.000000     915.000      2665.0         NaN         NaN
# 5139   2473.000000    2774.000      3161.0         NaN         NaN
# 5693   4380.000000    4027.000         NaN         NaN         NaN
# 6197   3635.000000    3987.000      3748.0         NaN         NaN
# 6301   3063.000000    3123.000      3521.0         NaN         NaN
# 6350   3919.000000    3542.000      3712.0         NaN         NaN
# 7266   3030.000000    2283.000         NaN         NaN         NaN
# 7529   3626.000000       0.000         NaN         NaN         NaN
# 8165   2988.000000    2793.000         0.0         NaN         NaN
# 8242   2727.000000    2471.000      2964.0         NaN         NaN
# 9061   3796.000000    3989.000         NaN         NaN         NaN
# 10769  1894.000000    1968.000      2351.0         NaN         NaN
# 10957  1356.000000    1778.000      3311.0         NaN         NaN
# 13760  2351.000000    2282.000         NaN         NaN         NaN
# 13860  1422.000000    3005.000         NaN         NaN         NaN
# 15518  2988.000000    2910.000      2617.0         NaN         NaN
# 16847  2867.000000    2935.000      4026.0         NaN         NaN
# 16943  3911.000000    4098.000      4253.0         NaN         NaN
# 17148  3720.000000    4086.000      3624.0         NaN         NaN
#
# [29 rows x 32 columns]

# %%
#Définition de la fonction Loss (pour une colonne du dataset)
def Loss(x):
    # ybarre=

# %%
from sklearn.decomposition import PCA
data = df[["District","Crop","2011 Yield","2012 Yield","SI Per Ha (Inr/Ha)","Indemnity Level"]]
data2 = data.copy(deep = True)
data2.drop(columns=["Crop"])
data2 = pd.get_dummies(data2)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(data2)
data['pca-one'] = pca_result[:,0]
data['pca-two'] = pca_result[:,1] 
plt.figure(figsize=(16,10))
sn.scatterplot(
    x="pca-one", y="pca-two",
    hue="Crop",
    data=data,
    palette=sn.color_palette(palette="bright",n_colors=20),
    legend="full",
    alpha=0.3
)
# Out:
# C:\Users\marti\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\marti\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# <AxesSubplot:xlabel='pca-one', ylabel='pca-two'>

# %%
pca.components_
# Out:
# array([[ 5.36392358e-01,  5.11255722e-01,  6.71491493e-01,
#          5.93024592e-07, -3.51322049e-06,  1.33954451e-06,
#          8.25829486e-07,  5.74671947e-07,  4.33838381e-07,
#          1.30947905e-06,  3.44874488e-07,  2.78062783e-07,
#         -1.71799276e-06,  7.46202227e-08, -8.29618847e-07,
#          2.18637809e-07,  6.61273421e-07, -5.75515588e-06,
#         -4.72621657e-07, -1.50880796e-07,  1.14946939e-07,
#          7.07779658e-08,  6.00876918e-09,  5.00330228e-09,
#         -1.31131574e-08, -3.12976290e-08, -1.12518335e-09,
#         -1.30036062e-07, -1.49420189e-07, -6.36484960e-08,
#         -3.68569505e-08, -8.16990030e-08,  9.41024845e-07,
#          3.53901106e-06,  2.39123486e-06, -1.40091216e-07,
#         -4.20615258e-08],
#        [-4.88578880e-01, -4.60650398e-01,  7.41007346e-01,
#         -5.85640974e-07, -1.11137085e-05,  5.81448073e-08,
#          3.67249215e-06,  2.79172412e-06,  7.85383786e-07,
#          2.72889028e-06,  3.68806441e-07, -1.67808449e-06,
#         -3.17899257e-06,  2.04522694e-06,  2.04977036e-06,
#          1.05035725e-06,  4.19989421e-07, -1.75488058e-05,
#         -1.67228730e-06, -4.74417963e-07,  5.26674148e-07,
#          3.16411855e-07,  2.63919457e-08,  3.16330122e-08,
#          1.12671378e-08, -8.75907367e-08, -3.43116274e-09,
#         -4.03556622e-07, -5.18428126e-07, -2.51527741e-07,
#         -1.13139426e-07, -2.78299584e-07,  2.68482263e-05,
#         -2.44335871e-06, -3.41305103e-06, -4.09037921e-07,
#         -1.43672308e-07]])
