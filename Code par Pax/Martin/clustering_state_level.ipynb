# %% [markdown]
# # Clustering at state level

# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

from sklearn.preprocessing import PowerTransformer
from utils import add_Loss, clean_data_state

from pyclustering.utils.metric import distance_metric, type_metric
from pyclustering.cluster.kmeans import kmeans
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer,random_center_initializer

# %% [markdown]
# ## Import and clean data

# %%
#Select the dataset of one season of one year
YEAR = 2019
SEASON = "Kharif" # or "Kharif" 

#Path to the dataset
pathData = f"Data\RawDataUnified\RawData_{YEAR}_{SEASON}"
print(pathData)


df = pd.read_csv(pathData)

#Clean an add loss to data
df=add_Loss(clean_data_state(df))
df
# Out:
# Data\RawDataUnified\RawData_2019_Kharif
# C:\Users\marti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                     State  ...          Loss
# key                                                        ...
# andhra pradesh_anantapur_agali__agali                   0  ...  14230.814316
# andhra pradesh_anantapur_agali__akkagaladevarah...      0  ...  14464.016467
# andhra pradesh_anantapur_agali__hulikeradevarah...      0  ...  14230.814316
# andhra pradesh_anantapur_agali__inagalore               0  ...  14464.016467
# andhra pradesh_anantapur_agali__kodihalli               0  ...  14230.814316
# ...                                                   ...  ...           ...
# west bengal_uttar dinajpur__hemtabad__                 13  ...   5086.938832
# west bengal_uttar dinajpur__itahar__                   13  ...   5086.938832
# west bengal_uttar dinajpur__kaliaganj__                13  ...   5086.938832
# west bengal_uttar dinajpur__karandighi__               13  ...   5086.938832
# west bengal_uttar dinajpur__raiganj__                  13  ...   5086.938832
#
# [372909 rows x 24 columns]

# %% [markdown]
# ## Preprocessing et fonctions utiles K-Means

# %%
data = pd.get_dummies( df, columns=["Crop"])

for c in data.columns:
    if c != "State":
        pt = PowerTransformer()
        data.loc[:, c] = pt.fit_transform(np.array(data[c]).reshape(-1, 1))

data_list =data.to_numpy()

# %%
def tab_cluster(clusters,donnees):
    tab_clusters = np.zeros(len(donnees)) #tab_clusters[i] renvoit le numéro de cluster de la i-ème ligne
    for i in range(k):
        for x in clusters[i]:
            tab_clusters[x] = i
    return tab_clusters

list_state = pd.unique(pd.read_csv(pathData)["State"])

def get_liste_state_cluster(clusters,donnees):
    df2 = donnees.copy(deep = True)
    df2["Cluster"] = tab_cluster(clusters,donnees)
    liste_state_cluster = []
    for i in range(len(list_state)):
        l = []
        l.append(list_state[i])
        l.append(np.bincount(df2[df2["State"] == i]["Cluster"].to_numpy().astype(int)).argmax())
        liste_state_cluster.append(l)
    return liste_state_cluster
# Out:
# C:\Users\marti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## K-Means avec distance perso

# %%
# Définition d'une distance entre deux parcelles avec forte pénalisation si état différent

def distance_state_penalized(point1, point2):
    if point1[0] == point2[0]:
        result = 0.0
    else:
        result = 9*10**15
    p1_numpy = np.array(point1[1:])
    p2_numpy = np.array(point2[1:])
    result += np.linalg.norm(p1_numpy-p2_numpy)
    return result

metric_perso = distance_metric(type_metric.USER_DEFINED, func=distance_state_penalized)

# %%
# Nombre de clusters
k = 7

# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(data_list, k).initialize()
 
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(data_list, initial_centers,metric = metric_perso)
 
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()

# %%
liste_state_cluster = get_liste_state_cluster(clusters,df)
liste_state_cluster
# Out:
# [['Andhra Pradesh', 1],
#  ['Chhattisgarh', 0],
#  ['Gujarat', 0],
#  ['Haryana', 0],
#  ['Jharkhand', 0],
#  ['Karnataka', 3],
#  ['Madhya Pradesh', 0],
#  ['Maharashtra', 0],
#  ['Odisha', 1],
#  ['Rajasthan', 0],
#  ['Telangana', 6],
#  ['Uttar Pradesh', 0],
#  ['Uttarakhand', 1],
#  ['West Bengal', 2]]

# %% [markdown]
# ## K-Means avec définition d'une distance entre états

# %%
# regroupement des données par états
liste_df = []
for col in data.columns:
    if col != "State":
        df_by_state_prov = data.groupby("State")
        df_by_state_prov = df_by_state_prov[col].apply(np.array).to_frame()
        liste_df.append(df_by_state_prov[col])

df_by_state = pd.concat(liste_df,axis=1)
df_by_state
# Out:
#                                           Area Sown (Ha)  \
# State
# 0      [0.20916218398224784, 0.20916218398224784, 0.2...
# 1      [0.20916218398224784, 0.20916218398224784, 0.2...
# 2      [7.050761498846274, 7.050761498846274, 7.05076...
# 3      [0.20916218398224784, 0.20916218398224784, 0.2...
# 4      [0.20916218398224784, 0.20916218398224784, 0.2...
# 5      [0.20916218398224784, 0.20916218398224784, 0.2...
# 6      [0.20916218398224784, 0.20916218398224784, 0.2...
# 7      [0.20916218398224784, 0.20916218398224784, 0.2...
# 8      [0.5208119786453852, 0.5208119786453852, 0.520...
# 9      [0.20916218398224784, 0.20916218398224784, 0.2...
# 10     [-3.5165350337553085, -3.5165350337553085, -3....
# 11     [0.20916218398224784, 0.20916218398224784, 0.2...
# 12     [0.20916218398224784, 0.20916218398224784, 0.2...
#
#                                        Area Insured (Ha)  \
# State
# 0      [1.0037981936405962, 1.0037981936405962, 1.003...
# 1      [1.749281624952688, 1.749281624952688, 1.74928...
# 2      [1.915209111952602, 1.915209111952602, 1.91520...
# 3      [-0.6705790084849246, -0.6705790084849246, -0....
# 4      [0.5313301770620714, 1.484804570751764, 1.4848...
# 5      [2.476546658670638, 2.3349939283083407, 2.5919...
# 6      [1.0037981936405962, 1.0037981936405962, 1.003...
# 7      [1.2376343787946489, 1.2376343787946489, 1.237...
# 8      [0.9897507013259682, 0.9897507013259682, 0.989...
# 9      [0.7195561637445752, 0.7195561637445752, 0.719...
# 10     [-0.4984204183442142, -0.4984204183442142, -0....
# 11     [-1.2441725679490887, -1.2441725679490887, -1....
# 12     [1.6337841652640945, 1.6337841652640945, 1.633...
#
#                                       SI Per Ha (Inr/Ha)  \
# State
# 0      [-0.8085527423744752, -0.8085527423744752, -0....
# 1      [-2.6891035672027668, -2.6891035672027668, -2....
# 2      [-0.8085527423744752, -0.8085527423744752, -0....
# 3      [-0.1877826320820115, -0.1877826320820115, -0....
# 4      [1.4773242841777199, -0.6770289127641277, -0.6...
# 5      [-0.49262377733293433, -2.5648917163062284, -0...
# 6      [-1.3303836151674406, -1.3303836151674406, -1....
# 7      [0.7522227114754839, 0.7522227114754839, 0.752...
# 5      [0.5127516709866342, 0.5127516709866342, 0.512...
# 6      [0.5127516709866342, 0.5127516709866342, 0.512...
# 7      [0.5127516709866342, 0.5127516709866342, 0.512...
# 8      [0.5127516709866342, 0.5127516709866342, 0.512...
# 9      [0.5127516709866342, 0.5127516709866342, 0.512...
# 10     [-0.16766964804560655, -0.16766964804560655, -...
# 11     [-0.9219429712368179, -0.9219429712368179, -0....
# 12     [0.5127516709866342, 0.5127516709866342, 0.512...
#
#                                               2004 Yield  \
# State
# 0      [0.5446061435624959, 0.5446061435624959, 0.544...
# 1      [0.5446061435624959, 0.5446061435624959, 0.544...
# 2      [0.5446061435624959, 0.5446061435624959, 0.544...
# 3      [0.5446061435624959, 0.5446061435624959, 0.544...
# 4      [0.5446061435624959, 0.5446061435624959, 0.544...
# 5      [0.5446061435624959, 0.5446061435624959, 0.544...
# 6      [0.5446061435624959, 0.5446061435624959, 0.544...
# 7      [0.5446061435624959, 0.5446061435624959, 0.544...
# 8      [0.5446061435624959, 0.5446061435624959, 0.544...
# 9      [-0.2254479701185798, -0.08597046289447266, 0....
# 10     [-0.27685887491982214, -0.27685887491982214, -...
# 11     [-0.8399379045547994, -0.8399379045547994, -0....
# 12     [0.5446061435624959, 0.5446061435624959, 0.544...
#
#                                               2005 Yield  \
# State
# 0      [0.6335774660125708, 0.6335774660125708, 0.633...
# 1      [0.6335774660125708, 0.6335774660125708, 0.633...
# 2      [0.6335774660125708, 0.6335774660125708, 0.633...
# 3      [0.6335774660125708, 0.6335774660125708, 0.633...
# 4      [0.6335774660125708, 0.6335774660125708, 0.633...
# 5      [0.6335774660125708, 0.6335774660125708, 0.633...
# 6      [0.6335774660125708, 0.6335774660125708, 0.633...
# 7      [0.6335774660125708, 0.6335774660125708, 0.633...
# 8      [0.6335774660125708, 0.6335774660125708, 0.633...
# 9      [0.14627632098860388, 0.2834968348694667, 0.24...
# 10     [0.23535176842716826, 0.23535176842716826, 0.2...
# 11     [-0.5721804803891958, -0.5721804803891958, -0....
# 12     [0.0602285387843921, 0.0602285387843921, 0.060...
#
#                                               2006 Yield  ...  \
# State                                                     ...
# 0      [-1.9721020411963335, -1.9721020411963335, -1....  ...
# 1      [0.6465804074530026, 0.6465804074530026, 0.646...  ...
# 2      [-0.27025706315655096, -0.23473732115032503, -...  ...
# 3      [0.6465804074530026, 0.6465804074530026, 0.646...  ...
# 4      [0.6465804074530026, 0.6465804074530026, 0.646...  ...
# 5      [0.6465804074530026, 0.6465804074530026, 0.646...  ...
# 6      [0.6465804074530026, 0.6465804074530026, 0.646...  ...
# 7      [0.5920465032906786, 0.5920465032906786, 0.592...  ...
# 8      [0.061900711470074934, 0.061900711470074934, 0...  ...
# 9      [0.525928625684331, 0.462831329060656, 0.59929...  ...
# 10     [0.2905137453986016, 0.2905137453986016, 0.290...  ...
# 11     [-1.0145563877723887, -1.0145563877723887, -1....  ...
# 12     [0.42736212262975376, 0.42736212262975376, 0.4...  ...
#
#                                       Crop_Sunflower IRR  \
# State
# 0      [-0.03317245525030668, -0.03317245525030668, -...
# 1      [-0.03317245525030668, -0.03317245525030668, -...
# 2      [-0.009391268334929882, -0.009391268334929882,...
# 3      [-0.009391268334929882, -0.009391268334929882,...
# 4      [-0.009391268334929882, -0.009391268334929882,...
# 5      [-0.009391268334929882, -0.009391268334929882,...
# 6      [-0.009391268334929882, -0.009391268334929882,...
# 7      [-0.009391268334929882, -0.009391268334929882,...
# 8      [-0.009391268334929882, -0.009391268334929882,...
# 9      [-0.009391268334929882, -0.009391268334929882,...
# 10     [-0.009391268334929882, -0.009391268334929882,...
# 11     [-0.009391268334929882, -0.009391268334929882,...
# 12     [-0.009391268334929882, -0.009391268334929882,...
#
#                                                Crop_Urad  \
# State
# 0      [-0.03903284747662696, -0.03903284747662696, -...
# 1      [-0.03903284747662696, -0.03903284747662696, -...
# 2      [-0.03903284747662696, -0.03903284747662696, -...
# 3      [-0.03903284747662696, -0.03903284747662696, -...
# 4      [-0.03903284747662696, -0.03903284747662696, -...
# 5      [-0.03903284747662696, -0.03903284747662696, -...
# 6      [-0.03903284747662696, -0.03903284747662696, -...
# 7      [-0.03903284747662696, -0.03903284747662696, -...
# 8      [-0.03903284747662696, -0.03903284747662696, -...
# 9      [-0.03903284747662696, -0.03903284747662696, -...
# 10     [-0.03903284747662696, -0.03903284747662696, -...
# 11     [-0.03903284747662696, -0.03903284747662696, -...
# 12     [-0.03903284747662696, -0.03903284747662696, -...
#
#                                         Crop_Urad Un-IRR  \
# State
# 0      [-0.006398919559813339, -0.006398919559813339,...
# 1      [-0.006398919559813339, -0.006398919559813339,...
# 2      [-0.006398919559813339, -0.006398919559813339,...
# 3      [-0.006398919559813339, -0.006398919559813339,...
# 4      [-0.006398919559813339, -0.006398919559813339,...
# 5      [-0.006398919559813339, -0.006398919559813339,...
# 6      [-0.006398919559813339, -0.006398919559813339,...
# 7      [-0.006398919559813339, -0.006398919559813339,...
# 8      [-0.006398919559813339, -0.006398919559813339,...
# 9      [-0.006398919559813339, -0.006398919559813339,...
# 10     [-0.006398919559813339, -0.006398919559813339,...
# 11     [-0.006398919559813339, -0.006398919559813339,...
# 12     [-0.006398919559813339, -0.006398919559813339,...
#
#                                               Crop_Wheat  \
# State
# 0      [-0.4960667663993583, -0.4960667663993583, -0....
# 1      [-0.4960667663993583, -0.4960667663993583, -0....
# 2      [-0.4960667663993583, -0.4960667663993583, -0....
# 3      [-0.4960667663993583, -0.4960667663993583, -0....
# 4      [-0.4960667663993583, -0.4960667663993583, -0....
# 5      [-0.4960667663993583, -0.4960667663993583, -0....
# 6      [-0.4960667663993583, -0.4960667663993583, -0....
# 7      [-0.4960667663993583, -0.4960667663993583, -0....
# 8      [-0.4960667663993583, -0.4960667663993583, -0....
# 9      [-0.4960667663993583, -0.4960667663993583, -0....
# 10     [-0.4960667663993583, -0.4960667663993583, -0....
# 11     [-0.4960667663993583, -0.4960667663993583, -0....
# 12     [-0.4960667663993583, -0.4960667663993583, -0....
#
#                                           Crop_Wheat IRR  \
# State
# 0      [-0.25729600938596, -0.25729600938596, -0.2572...
# 1      [-0.25729600938596, -0.25729600938596, -0.2572...
# 2      [-0.25729600938596, -0.25729600938596, -0.2572...
# 3      [-0.25729600938596, -0.25729600938596, -0.2572...
# 4      [-0.25729600938596, -0.25729600938596, -0.2572...
# 5      [-0.25729600938596, -0.25729600938596, -0.2572...
# 6      [-0.25729600938596, -0.25729600938596, -0.2572...
# 7      [-0.25729600938596, -0.25729600938596, -0.2572...
# 8      [-0.25729600938596, -0.25729600938596, -0.2572...
# 9      [-0.25729600938596, -0.25729600938596, -0.2572...
# 10     [-0.25729600938596, -0.25729600938596, -0.2572...
# 11     [-0.25729600938596, -0.25729600938596, -0.2572...
# 12     [-0.25729600938596, -0.25729600938596, -0.2572...
#
#                                        Crop_Wheat Un-IRR
# State
# 0      [-0.10462685378575722, -0.10462685378575722, -...
# 1      [-0.10462685378575722, -0.10462685378575722, -...
# 2      [-0.10462685378575722, -0.10462685378575722, -...
# 3      [-0.10462685378575722, -0.10462685378575722, -...
# 4      [-0.10462685378575722, -0.10462685378575722, -...
# 5      [-0.10462685378575722, -0.10462685378575722, -...
# 6      [-0.10462685378575722, -0.10462685378575722, -...
# 7      [-0.10462685378575722, -0.10462685378575722, -...
# 8      [-0.10462685378575722, -0.10462685378575722, -...
# 9      [-0.10462685378575722, -0.10462685378575722, -...
# 10     [-0.10462685378575722, -0.10462685378575722, -...
# 11     [-0.10462685378575722, -0.10462685378575722, -...
# 12     [-0.10462685378575722, -0.10462685378575722, -...
#
# [13 rows x 78 columns]

# %%
# Nombre de clusters
k = 3

# Prepare initial centers using K-Means++ method.
initial_centers = random_center_initializer(df_by_state, k).initialize()
 
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(df_by_state, initial_centers)
 
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 8
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13568/1771055720.py in <module>
#       3
#       4 # Prepare initial centers using K-Means++ method.
# ----> 5 initial_centers = random_center_initializer(df_by_state, k).initialize()
#       6
#       7 # Create instance of K-Means algorithm with prepared centers.
#
# ~\anaconda3\lib\site-packages\pyclustering\cluster\center_initializer.py in initialize(self, **kwargs)
#      71             return self.__data[:]
#      72
# ---> 73         return [self.__create_center(return_index) for _ in range(self.__amount)]
#      74
#      75
#
# ~\anaconda3\lib\site-packages\pyclustering\cluster\center_initializer.py in <listcomp>(.0)
#      71             return self.__data[:]
#      72
# ---> 73         return [self.__create_center(return_index) for _ in range(self.__amount)]
#      74
#      75
#
# ~\anaconda3\lib\site-packages\pyclustering\cluster\center_initializer.py in __create_center(self, return_index)
#      89         if return_index:
#      90             return random_index_point
# ---> 91         return self.__data[random_index_point]
#      92
#      93
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 8

# %%
# Distance entre états

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(metric=metric_perso).fit(pd.get_dummies( df, columns=["Crop"]).to_numpy())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10540/531887129.py in <module>
#       1 from sklearn.cluster import DBSCAN
# ----> 2 clustering = DBSCAN(metric=metric_perso).fit(pd.get_dummies( df, columns=["Crop"]).to_numpy())
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     373         neighbors_model.fit(X)
#     374         # This has worst case O(n^2) memory complexity
# --> 375         neighborhoods = neighbors_model.radius_neighbors(X, return_distance=False)
#     376
#     377         if sample_weight is None:
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#    1079                 results = neigh_dist, neigh_ind
#    1080             else:
# -> 1081                 neigh_ind_list = sum(chunked_results, [])
#    1082                 results = _to_object_array(neigh_ind_list)
#    1083
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1710         else:
#    1711             X_chunk = X[sl]
# -> 1712         D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1713         if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1714             metric, None
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1882         func = partial(distance.cdist, metric=metric, **kwds)
#    1883
# -> 1884     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1885
#    1886
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1423
#    1424     if effective_n_jobs(n_jobs) == 1:
# -> 1425         return func(X, Y, **kwds)
#    1426
#    1427     # enforce a threading backend to prevent data communication overhead
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _pairwise_callable(X, Y, metric, force_all_finite, **kwds)
#    1467         iterator = itertools.product(range(X.shape[0]), range(Y.shape[0]))
#    1468         for i, j in iterator:
# -> 1469             out[i, j] = metric(X[i], Y[j], **kwds)
#    1470
#    1471     return out
#
# ~\anaconda3\lib\site-packages\pyclustering\utils\metric.py in __call__(self, point1, point2)
#     130
#     131         """
# --> 132         return self.__calculator(point1, point2)
#     133
#     134
#
# ~\AppData\Local\Temp/ipykernel_10540/1981084949.py in distance_state_penalized(point1, point2)
#       7         result = 9*10**15
#       8     p1_numpy = np.array(point1[1:])
# ----> 9     p2_numpy = np.array(point2[1:])
#      10     result += np.linalg.norm(p1_numpy-p2_numpy)
#      11     return result
#
# KeyboardInterrupt:

# %%
len(np.unique(clustering.labels_))
# Out:
# 8001

# %% [markdown]
# ##  K Prototypes

# %%
from kmodes.kprototypes import KPrototypes

# %%
def get_liste_state_cluster_2(clusters,donnees):
    df2 = donnees.copy(deep = True)
    df2["Cluster"] = clusters
    liste_state_cluster = []
    for i in range(len(list_state)):
        l = []
        l.append(list_state[i])
        l.append(np.bincount(df2[df2["State"] == i]["Cluster"].to_numpy().astype(int)).argmax())
        liste_state_cluster.append(l)
    return liste_state_cluster

# %%
list_state = pd.unique(pd.read_csv(pathData)["State"])
# Out:
# C:\Users\marti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
kprot_data = df.copy()
#Pre-processing
for c in df.columns[2:]:
    pt = PowerTransformer()
    kprot_data[c] =  pt.fit_transform(np.array(kprot_data[c]).reshape(-1, 1))

categorical_columns = [0, 1]

# %%
def categorical_dissimilarity(a, b, **_):
    """Dissimilarity function with state penalization"""
    return np.sum(a[0] != b[0])*9*10**15 + np.sum(a[1] != b[1])

# %%
#Actual clustering
n_clusters = 4
kproto = KPrototypes(n_clusters= n_clusters, init='Cao', n_jobs = 4,cat_dissim=categorical_dissimilarity)
clusters = kproto.fit_predict(kprot_data, categorical=categorical_columns)

# %%
list_state_cluster = get_liste_state_cluster_2(clusters,df)
list_state_cluster
# Out:
# [['Andhra Pradesh', 3],
#  ['Chhattisgarh', 1],
#  ['Gujarat', 1],
#  ['Haryana', 1],
#  ['Jharkhand', 1],
#  ['Karnataka', 0],
#  ['Madhya Pradesh', 1],
#  ['Maharashtra', 0],
#  ['Odisha', 2],
#  ['Rajasthan', 0],
#  ['Telangana', 3],
#  ['Uttar Pradesh', 0],
#  ['Uttarakhand', 1],
#  ['West Bengal', 3]]

# %%
SEASON
# Out:
# 'Kharif'

# %% [markdown]
# ## Interprétation clusters

# %%
clusters_state =[3,3,3,3,1,3,1,2,3,2,3,1,3,3]
list_state
# Out:
# array(['Andhra Pradesh', 'Chhattisgarh', 'Gujarat', 'Haryana',
#        'Jharkhand', 'Karnataka', 'Madhya Pradesh', 'Maharashtra',
#        'Odisha', 'Rajasthan', 'Telangana', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
liste_crop = pd.unique(df["Crop"])
liste_crop
# Out:
# array(['Arhar', 'Paddy', 'Bajra', 'Castor', 'Chilli IRR', 'Chilli Un-IRR',
#        'Cotton IRR', 'Cotton Un-IRR', 'Groundnut', 'Groundnut IRR',
#        'Groundnut Un-IRR', 'Jowar', 'Maize', 'Moong', 'Navane',
#        'Sugarcane Plant', 'Sugarcane Ratoon', 'Sunflower', 'Urad',
#        'Onion', 'Turmeric', 'Paddy Un-IRR', 'Paddy IRR', 'Soybean',
#        'Ragi', 'Til (Sesame)', 'Moth', 'Banana', 'Cotton', 'Arhar IRR',
#        'Arhar Un-IRR', 'Bajra IRR', 'Bajra Un-IRR', 'Cabbage', 'Cowpea',
#        'Moong Un-IRR', 'Moth Un-IRR', 'Jowar IRR', 'Jowar Un-IRR',
#        'Maize IRR', 'Maize Un-IRR', 'ONION IRR', 'Onion Un-IRR',
#        'Potato Un-IRR', 'Potato IRR', 'Ragi Un-IRR', 'Ragi IRR',
#        'Save Un-IRR', 'Soybean Un-IRR', 'Soybean IRR', 'Sunflower Un-IRR',
#        'Sunflower IRR', 'Til (Sesame) Un-IRR', 'Tomato', 'Urad Un-IRR',
#        'KODO-KUTKI', 'Lentil (Masoor)', 'Niger Seed', 'Ginger',
#        'Guar Seed', 'Rice', 'TURMERIC', 'Aman paddy', 'Aus Paddy', 'Jute'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_copy = df.copy(deep=True)
df_copy["Crop"] = le.fit_transform(df_copy["Crop"])
crop_majoritaire = []
for i in range(len(list_state)):
    crop_majoritaire.append(liste_crop[np.bincount(df_copy[df_copy["State"]==i]["Crop"]).argmax()])
crop_majoritaire
# Out:
# ['Maize Un-IRR',
#  'Onion Un-IRR',
#  'Navane',
#  'Chilli Un-IRR',
#  'Maize Un-IRR',
#  'Arhar Un-IRR',
#  'Sunflower Un-IRR',
#  'Sunflower Un-IRR',
#  'Maize Un-IRR',
#  'Chilli Un-IRR',
#  'Soybean Un-IRR',
#  'Maize Un-IRR',
#  'Maize Un-IRR',
#  'Arhar']

# %%
crop_cluster =pd.DataFrame([ [clusters_state[i],crop_majoritaire[i]] for i in range(len(clusters_state))],columns = ["Cluster","Crop"])
crop_cluster
# Out:
#     Cluster              Crop
# 0         3      Maize Un-IRR
# 1         3      Onion Un-IRR
# 2         3            Navane
# 3         3     Chilli Un-IRR
# 4         1      Maize Un-IRR
# 5         3      Arhar Un-IRR
# 6         1  Sunflower Un-IRR
# 7         2  Sunflower Un-IRR
# 8         3      Maize Un-IRR
# 9         2     Chilli Un-IRR
# 10        3    Soybean Un-IRR
# 11        1      Maize Un-IRR
# 12        3      Maize Un-IRR
# 13        3             Arhar

# %%
sn.catplot(x='Crop', y='Cluster', kind="swarm", hue='Cluster', data=crop_cluster) #sample is use to shuffle the rows of the dataset
plt.xticks(rotation=90, ha='right')
plt.show()
